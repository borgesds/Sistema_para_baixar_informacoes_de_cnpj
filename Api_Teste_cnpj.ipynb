# %%
import pandas as pd
import requests
import json
import time

# %%
df = pd.read_csv('dataframe_cnpj.csv')
df['cnpj'] = df['cnpj'].astype(str)
df.head(10)
# Out:
#              cnpj  state  city  district  street  number  zip  ddd  phone
# 0  86506899000134    NaN   NaN       NaN     NaN     NaN  NaN  NaN    NaN
# 1  41234159000158    NaN   NaN       NaN     NaN     NaN  NaN  NaN    NaN
# 2  11339833000106    NaN   NaN       NaN     NaN     NaN  NaN  NaN    NaN
# 3  17232037000148    NaN   NaN       NaN     NaN     NaN  NaN  NaN    NaN
# 4  10346800000112    NaN   NaN       NaN     NaN     NaN  NaN  NaN    NaN
# 5  86506899000134    NaN   NaN       NaN     NaN     NaN  NaN  NaN    NaN
# 6  61877557000108    NaN   NaN       NaN     NaN     NaN  NaN  NaN    NaN
# 7   6408094000119    NaN   NaN       NaN     NaN     NaN  NaN  NaN    NaN
# 8   4638814000107    NaN   NaN       NaN     NaN     NaN  NaN  NaN    NaN
# 9  97607945000108    NaN   NaN       NaN     NaN     NaN  NaN  NaN    NaN

# %%
for i in range(len(df)):
    
    time.sleep(25)

    url = "https://consulta-cnpj-gratis.p.rapidapi.com/office/" + df.loc[i, 'cnpj']

    querystring = {"simples":"false"}

    headers = {
        'x-rapidapi-host': "consulta-cnpj-gratis.p.rapidapi.com",
        'x-rapidapi-key': "b57f08dc88msh5cb0d7e9c1a10b2p18f2a3jsndb630d71f7b8"
        }

    response = requests.request("GET", url, headers=headers, params=querystring)

    # Transforma o texto da resposta em um dicionário
    data = json.loads(response.text)
    
    # populando a tabela
    if data == {"code":404,"message":"cached data unavailable"}:
        df.loc[i, 'state'] = 'NA'
        
    elif 'state' in data['address']:
        df.loc[i, 'state'] = data['address']['state']
        
    else: 
        df.loc[i, 'state'] = 'NA'
        
    if data == {"code":404,"message":"cached data unavailable"}:
        df.loc[i, 'city'] = 'NA'
        
    elif 'city' in data['address']:
        df.loc[i, 'city'] = data['address']['city']
        
    else:
        df.loc[i, 'city'] = 'NA'
        
    if data == {"code":404,"message":"cached data unavailable"}:
        df.loc[i, 'district'] = 'NA'
        
    elif 'district' in data['address']:
        df.loc[i, 'district'] = data['address']['district']
        
    else:
        df.loc[i, 'district'] = 'NA'
        
    if data == {"code":404,"message":"cached data unavailable"}:
        df.loc[i, 'street'] = 'NA'
        
    elif 'street' in data['address']:
        df.loc[i, 'street'] = data['address']['street']
        
    else:
        df.loc[i, 'street'] = 'NA'
    
    if data == {"code":404,"message":"cached data unavailable"}:
        df.loc[i, 'number'] = 'NA'
        
    elif 'number' in data['address']:
        df.loc[i, 'number'] = data['address']['number']
        
    else:
        df.loc[i, 'number'] = 'NA'
        
    if data == {"code":404,"message":"cached data unavailable"}:
        df.loc[i, 'zip'] = 'NA'
        
    elif 'zip' in data['address']:
        df.loc[i, 'zip'] = data['address']['zip']
    
    else:
        df.loc[i, 'zip'] = 'NA'
        
    if data == {"code":404,"message":"cached data unavailable"}:
        df.loc[i, 'ddd'] = 'NA'
        
    elif data['phones']:
        ddd = data['phones']
        K = 'area'
        ddd = [sub[K] for sub in ddd if K in sub][0]
        df.loc[i, 'ddd'] = str(ddd)
    
    else:
        df.loc[i, 'ddd'] = 'NA'
        
    if data == {"code":404,"message":"cached data unavailable"}:
        df.loc[i, 'phone'] = 'NA'
        
    elif data['phones']:
        phone = data['phones']
        P = 'number'
        phone = [sub[P] for sub in phone if K in sub][0] 
        df.loc[i, 'phone'] = str(phone)
    
    else:
        df.loc[i, 'phone'] = 'NA'
    
    print(i)
    print('Tabulado CNPJ:' + df.loc[i, 'cnpj'])
# Out:
# 0
# Tabulado CNPJ:86506899000134
# 1
# Tabulado CNPJ:41234159000158
# 2
# Tabulado CNPJ:11339833000106
# 3
# Tabulado CNPJ:17232037000148
# 4
# Tabulado CNPJ:10346800000112
# 5
# Tabulado CNPJ:86506899000134
# 6
# Tabulado CNPJ:61877557000108
# 7
# Tabulado CNPJ:6408094000119
# 8
# Tabulado CNPJ:4638814000107
# 9
# Tabulado CNPJ:97607945000108
# 10
# Tabulado CNPJ:18065432000146
# 11
# Tabulado CNPJ:80296001000164
# 12
# Tabulado CNPJ:27179846000197
# 13
# Tabulado CNPJ:29068711000180
# 14
# Tabulado CNPJ:67458572000190
# 15
# Tabulado CNPJ:20314565000150
# 16
# Tabulado CNPJ:61457688000128
# 17
# Tabulado CNPJ:48516919000169
# 18
# Tabulado CNPJ:41234159000158
# 19
# Tabulado CNPJ:11339833000106
# 20
# Tabulado CNPJ:46097604000107
# 21
# Tabulado CNPJ:23594675000101
# 22
# Tabulado CNPJ:84888347000102
# 23
# Tabulado CNPJ:3158299000103
# 24
# Tabulado CNPJ:44969420000156
# 25
# Tabulado CNPJ:10393257000104
# 26
# Tabulado CNPJ:64826496000130
# 27
# Tabulado CNPJ:57916936000184
# 28
# ...

# %%
df
# Out:
#               cnpj state                           city  \
# 0   86506899000134    NA                             NA
# 1   41234159000158    PA                          Belém
# 2   11339833000106    SP                      Guarulhos
# 3   17232037000148    PR                        Marumbi
# 4   10346800000112    SP                           Tupã
# 5   86506899000134    NA                             NA
# 6   61877557000108    NA                             NA
# 7    6408094000119    GO                      Morrinhos
# 8    4638814000107    PR                       Curitiba
# 9   97607945000108    NA                             NA
# 10  18065432000146    MG                          Betim
# 11  80296001000164    NA                             NA
# 12  27179846000197    CE                       Redenção
# 13  29068711000180    RJ  São José do Vale do Rio Preto
# 14  67458572000190    NA                             NA
# 15  20314565000150    MA         Alto Alegre do Pindaré
# ...

# %% [markdown]
# # Modelos de como retirar atributos dentro de LISTA DICIONARIO

# %% [markdown]
# ## Método simplificado

# %%
test_list = data['phones']
print("The original list : " + str(test_list)) 
K = 'number'
res = [sub[K] for sub in test_list if K in sub][0] 
print("The extracted value : " + str(res)) 
res
# Out:
# The original list : [{'area': '91', 'number': '84086742'}]
# The extracted value : 84086742
# '84086742'

# %% [markdown]
# ## Método # 1: usando a compreensão de lista
#
# Essa é uma das maneiras pelas quais essa tarefa pode ser executada. Nela, iteramos para cada dicionário dentro da lista e verificamos se há uma chave nela, se estiver presente, o valor exigido é retornado.

# %%
test_list = [{"Gfg" : 3, "b" : 7},  
             {"is" : 5, 'a' : 10},  
             {"Best" : 9, 'c' : 11}] 
print("The original list : " + str(test_list)) 
K = 'Best'
res = [sub[K] for sub in test_list if K in sub][0] 
print("The extracted value : " + str(res))
# Out:
# The original list : [{'Gfg': 3, 'b': 7}, {'is': 5, 'a': 10}, {'Best': 9, 'c': 11}]
# The extracted value : 9

# %% [markdown]
# ## Método 2: Usando update() + loop
#
# Esta é mais uma maneira pela qual essa tarefa pode ser realizada. Nisto, atualizamos cada dicionário um no outro. Formando um grande dicionário, o valor é extraído deste dicionário.

# %%
test_list = [{"Gfg" : 3, "b" : 7},  
             {"is" : 5, 'a' : 10},  
             {"Best" : 9, 'c' : 11}] 
print("The original list : " + str(test_list)) 
K = 'Best'

res = dict() 
for sub in test_list: 
      
    res.update(sub) 
print("The extracted value : " + str(res[K]))
# Out:
# The original list : [{'Gfg': 3, 'b': 7}, {'is': 5, 'a': 10}, {'Best': 9, 'c': 11}]
# The extracted value : 9
